# %%
1.What are the two values of the Boolean data type? How do you write them?
True , False

2. What are the three different types of Boolean operators?
and or not

3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).
For and operator combination:
    True and True=True
    True and False=False
    False and False=False
For or operator combination:
    True or True =True
    True or False=True
    False or False=False
For not operator combination:
    not True =False
    not False=True
    
4. What are the values of the following expressions?
(5 > 4) and (3 == 5):False
not (5 > 4):False
(5 > 4) or (3 == 5):True
not ((5 > 4) or (3 == 5)):False
(True and True) and (True == False):False
(not False) or (not True):True
    
5. What are the six comparison operators?
<,>,<=,>=,==,!=

6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
a=5 :This assignment will return a is equal to 5
a==5 :This operation will return True or False as it compare the value of a whether its equal to 5 or not.

7. Identify the three blocks in this code:
spam = 0
if spam == 10: #first block
print('eggs')
if spam > 5: #second block
print('bacon')
else: #third block
print('ham')
print('spam')
print('spam')

8. Write code 
that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.
spam=int(input("Enter the value of spam: "))
if spam==1:
    print('Hello')
if else spam==2:
    print('Howdy')
else:
    print('Greetings!')


9.If your programme is stuck in an endless loop, what keys you’ll press?
break

10. How can you tell the difference between break and continue?
1>both break and continue are keywords used to manipulate the loop condition .Whenever we need to stop the iteration in a loop we use break statement
2>whereas whenever we need to continue the iteation and not letting interpreter to follow the iteration and restart the in process iteration again.Examples:
for break:
    i=0
    while i>=0:
        i+=1
        print(i)
        break           #here the endless loop wont go for endless loop and will break after the first iteration itself with returning value i=1

for continue:
    i=0
    while i<5:
        i+=1
        print(i)
        continue # here because of continue use we could stop while endless loop 
        i-=1
        
11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
range(10):it return 0-9
range(0,10):It will return 0-9
range(0,10,1):It will return 0-9 with +1 step on.

12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.
for i in range(1,11):
    print(i)

i=1
while i<=10:
    print(i)
    i+=1
    
13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?

spam.bacon()
