# %%
1. Why are functions advantageous to have in your programs?
Functions helps in reusability ,helps in reducing code error ,helps to reduce the size of the execution of code gives clearity in code readability
and modification in the program is simpler rather than typing the entire code again .

2. When does the code in a function run: when it's specified or when it's called?
    when its called
    
3. What statement creates a function?
with keyword def used before writing a function definition .for eg
def sum(a,b): #definition of sum function with def keyword
    return a+b

4. What is the difference between a function and a function call?
fucntion is equiped with a parameters and its function body whereas in function call its passed with arguments that triggers the parameters and body of the function.
for eg:
    def multiply(a,b):#function with its parameters
        return a*b  #{function- 
        m=multiply(3,5)        body   }
    print(m)  #function is called with arguments
    
5. How many global scopes are there in a Python program? How many local scopes?
In python program there is only one global scope is there and the scope remains till the termination of the code.
Local scope ramains till the execution of the function scope
for eg:
a=10          # a is a global variable and it exist till execution of this code .
def sum(a,b):
    c=20      # c is a local variable and its scope exists within the body of sum function
    return a+b
print('a value:',a) #here interpreter could able to read gloabal variable a
print('c value:',c) #here calling the value of c will fetch error as its not defined because c was a local variable
print(sum(5,6))


6. What happens to variables in a local scope when the function call returns?
local variable get erased from the memory after the function call returns

7. What is the concept of a return value? Is it possible to have a return value in an expression?
return value gives the value of the data in its best format available at the time of execution.
For eg:
        a=9
        return a #this will return value as 9 and the datatype of a will be int type
Yes we can have a return value in an expression like : return a+b

8. If a function does not have a return statement, what is the return value of a call to that function?
It will return none type
for eg:
def math():
    pass

print(type(math()))

9. How do you make a function variable refer to the global variable?

10. What is the data type of None?
none type

11. What does the sentence import areallyourpetsnamederic do?
it will import module name areallyourpetsnamederic

12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
spam.bacon()

13. What can you do to save a programme from crashing if it encounters an error?
we can use exceptional handling with try , except and finally  concept

14. What is the purpose of the try clause? What is the purpose of the except clause?
try is a keyword which does a trial on the code and after a verification if it fetches any error it sequence it to the except clause which handles the error and gives desired output.
For eg:
 try:
    a,b=10,0
    c=a/b
    print(c)
except Exception as e:

    print('Error found'+' making b value to 1 for progranm to not crash')
    b=1
    c=a/b
    print(c)
finally:

    print('Value is handled')
